# %% [markdown]
# # Variables and Printing
# - `Variables` can store different data types such as float (decimal) numbers , integers, strings, boolean values and more complex data structures such as lists, tuples, and dictionaries.
# - `Variables` can start with a '_' or a letter. They cannot start with a number.
# - Use the `print()` function for outputting data. This is the simplest way to test your code.
# - Use the `type()` function for checking the type of variable.
#     - Strings '' or "" are character variables
#     - Ints are integers or whole numbers
#     - Floats are decimal numbers
#     - Boolean values are assigned True or Fal

# %% [markdown]
# ## Exercise 1: Strings

# %%
protein= 'hemoglobin'
print(type(protein))
print(protein)
# Out:
# <class 'str'>
# hemoglobin

# %% [markdown]
# #### Trouble shooting practice:

# %%
aminoacid= 'alanine"
print(AminoAcid)

# %% [markdown]
# Desired output: alanine

# %% [markdown]
# ##### **note: Python stores memory and differentiates between uppercase and lowercase

# %%
## Your turn

# %% [markdown]
# Desired output: helium

# %% [markdown]
# ## Exercise 2: Intergers

# %%
carbon=6
print(type(carbon))
print('Carbon has',carbon,'atoms')
# Out:
# <class 'int'>
# Carbon has 6 atoms

# %% [markdown]
# #### Trouble shooting practice:

# %%
oxygen='8'
print(Oxygen has,oxygen,atoms)

# %% [markdown]
# Desired output: Oxygen has 8 atoms

# %%
## Your turn

# %% [markdown]
# Desired output: Nitrogen has 7 atoms

# %% [markdown]
# ## Exercise 3: Floats

# %%
a = 1.00
print(type(a))
print(a)
# Out:
# <class 'float'>
# 1.0

# %%
## Your turn

# %% [markdown]
# Desired output: 7.0

# %% [markdown]
# ## Exercise 4: Tuples
# ##### Tuples are list that cannot be changed

# %%
a=(1,2,3)
print(type(a))
print(a)
# Out:
# <class 'tuple'>
# (1, 2, 3)

# %%
b=(1234)
print(B)

# %% [markdown]
# Desired output:(1,2,3,4)

# %% [markdown]
# ## Exercise 5: Lists

# %%
a = ['a', 'b', 'c']
print(a)
print(type(a))
# Out:
# ['a', 'b', 'c']
# <class 'list'>

# %% [markdown]
# #### Troubleshooting practice

# %%
b= ('A','T','G','C')
print(b)
print(type(b))
# Out:
# ('A', 'T', 'G', 'C')
# <class 'tuple'>

# %% [markdown]
# Desired output: make sure it says class list
# ['A', 'T', 'G', 'C']

# %% [markdown]
# ## AI prompts:
# ##### Give me 10 beginner-friendly Python practice exercises using integers, floats, strings, lists, and tuples. Each exercise should be short, include a real-world example (like cooking, sports, or lab experiments), and ask me to create variables, do a simple calculation, or print something. Provide the expected output too.
