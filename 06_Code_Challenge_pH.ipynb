# %% [markdown]
# # Code Challenge: The pH scale.
#
# The pH scale is a logarithmic scale used to specify the acidity or basicity of an aqueous solution. It is an essential concept in biochemistry for understanding the behavior of biomolecules, enzymes, and cellular processes that are pH-dependent.
#
# ## Definition of pH
#
# The pH of a solution is defined as the negative logarithm (base 10) of the hydrogen ion concentration:
#
# $$ pH = -\log_{10} [H^+] $$
#
# where $[H^+]$ is the concentration of hydrogen ions in moles per liter (M).
#
# ## Derivation
#
# The derivation of the pH scale is based on the dissociation of water:
#
# $$ H_2O \leftrightarrow H^+ + OH^- $$
#
# At 25°C (298 K), the equilibrium constant ($K_w$) for this reaction is:
#
# $$ K_w = [H^+][OH^-] = 1.0 \times 10^{-14} \, \text{M}^2 $$
#
# For neutral water at this temperature:
#
# $$ [H^+] = [OH^-] = \sqrt{K_w} = 1.0 \times 10^{-7} \, \text{M} $$
#
# Thus, the pH of neutral water is:
#
# $$ pH = -\log_{10} [1.0 \times 10^{-7}] = 7.0 $$
#
# ## Acidity and Basicity
#
# - **Acidic solutions:** Have higher $[H^+]$ and thus lower pH (pH < 7).
# - **Basic (alkaline) solutions:** Have lower $[H^+]$ and thus higher pH (pH > 7).
#
# ## Importance in Biochemistry
#
# - **Enzyme Activity:** Most enzymes have an optimal pH range. Deviations from this range can alter the enzyme's structure and function.
# - **Protein Structure:** pH affects the ionization of amino acids, influencing protein structure and interactions.
# - **Metabolic Processes:** Many metabolic processes are pH-dependent and require tight regulation of intracellular pH.
#
# ## Henderson-Hasselbalch Equation
#
# Strong acids/bases will dissociate completely and the pH can be calculated from the total $[H^+]$ and $[OH^-]$. For weak acid/base solutions, the pH can be estimated using the Henderson-Hasselbalch equation:
#
# $$ pH = pKa + \log_{10} \left( \frac{[A^-]}{[HA]} \right) $$
#
# where $pKa$ is the acid dissociation constant, $[A^-]$ is the concentration of the conjugate base, and $[HA]$ is the concentration of the acid. The $pKa$ is a constant under specified conditions, and represents the dissociation state at which $[H^+] = [OH^-]$.
#
# This equation is particularly useful in biochemistry for designing buffer systems that maintain a constant pH in biological experiments.d maintaining the homeostasis of biological systems.

# %% [markdown]
# ## Code Examples

# %%
# Import necessary libraries
import numpy as np

# Challenge 1: Create a function to calculate pH from Hydrogen Ion Concentration
# The pH of a solution is defined as the negative logarithm (base 10) of the hydrogen ion concentration.
def calculate_ph(hydrogen_ion_concentration):
    """
    Calculate the pH of a solution given the hydrogen ion concentration.
    :param hydrogen_ion_concentration: Concentration of hydrogen ions in moles per liter (M)
    :return: pH value
    """
    return -np.log10(hydrogen_ion_concentration)

# Example usage
h_concentration = 1e-7  # 0.0000001 M
print(f"pH of the solution: {calculate_ph(h_concentration)}")

# Challenge 2: Determine the Acidity or Basicity of a Solution
# A pH less than 7 is acidic, pH equal to 7 is neutral, and pH greater than 7 is basic.
def solution_character(ph):
    """
    Determine the acidity or basicity of a solution based on its pH.
    :param ph: pH value
    :return: Character of the solution - Acidic, Neutral, or Basic
    """
    if ph < 7:
        return "Acidic"
    elif ph > 7:
        return "Basic"
    else:
        return "Neutral"

# Example usage
ph_value = 7.4
print(f"Solution character: {solution_character(ph_value)}")

# Challenge 3: Calculate the pH of a Diluted Acid
# pH changes when an acid is diluted. This challenge involves calculating the new pH after dilution.
def ph_after_dilution(initial_ph, dilution_factor):
    """
    Calculate the pH of an acid after dilution.
    :param initial_ph: Initial pH of the acid
    :param dilution_factor: Factor by which the acid is diluted
    :return: New pH value after dilution
    """
    initial_concentration = 10 ** (-initial_ph)
    diluted_concentration = initial_concentration / dilution_factor
    return calculate_ph(diluted_concentration)

# Example usage
initial_ph = 3
dilution_factor = 10
print(f"pH after dilution: {ph_after_dilution(initial_ph, dilution_factor)}")

# Challenge 4: Buffer Capacity Calculation
# Buffer capacity is a measure of a buffer solution's resistance to pH change upon the addition of an acid or base.
def buffer_capacity(ph, acid_concentration, base_concentration):
    """
    Calculate the buffer capacity of a solution.
    :param ph: pH of the buffer solution
    :param acid_concentration: Concentration of the acid in the buffer (M)
    :param base_concentration: Concentration of the base in the buffer (M)
    :return: Buffer capacity
    """
    # Henderson-Hasselbalch equation: pH = pKa + log([A-]/[HA])
    # Assuming pKa is known or can be calculated, buffer capacity can be estimated.
    # For simplicity, let's assume pKa = 7.4 for this buffer
    pKa = 7.4
    buffer_capacity = np.abs((base_concentration - acid_concentration) / (10 ** (ph - pKa)))
    return buffer_capacity

# Example usage
ph = 7.4
acid_concentration = 0.5  # M
base_concentration = 0.1  # M
print(f"Buffer capacity: {buffer_capacity(ph, acid_concentration, base_concentration)}")
# Out:
# pH of the solution: 7.0
# Solution character: Basic
# pH after dilution: 4.0
# Buffer capacity: 0.4

# %% [markdown]
# # Programming Challenge: pKa and Amino Acid Protonation State
#
# ## Background
# The protonation state of an amino acid in a solution is crucial in biochemistry, particularly in protein structure and function. The Henderson-Hasselbalch equation is often used to estimate this state. The equation is given by:
#
# $$ pH = pKa + \log_{10} \left( \frac{[A^-]}{[HA]} \right) $$
#
# where:
# - pH is the acidity of the solution.
# - pKa is the acid dissociation constant, a specific property of each amino acid.
# - $[{A}^-]$ is the concentration of the deprotonated form of the amino acid.
# - $[{HA}]$ is the concentration of the protonated form of the amino acid.
#
# ## Challenge
# Your task is to create a Python function that estimates the proportion of protonated amino acid molecules (\([\text{HA}]\)) in a solution at a given pH and pKa. The function should also plot the Henderson-Hasselbalch equation with pH on the y-axis and the incremental increase in base concentration (\([\text{A}^-]\)) on the x-axis.
#
# ### Function Requirements
# 1. **Function Name**: `estimate_protonation`
# 2. **Arguments**:
#    - `pKa`: Acid dissociation constant of the amino acid.
#    - `pH_range`: A range of pH values (as a list or array).
# 3. **Returns**:
#    - A plot showing the relationship between pH and the proportion of protonated amino acid.
#    - The proportion of protonated amino acid at each pH value in the given range.
# 4. **Plot Details**:
#    - X-axis: pH values.
#    - Y-axis: Proportion of protonated amino acid (\([\text{HA}]\)).
#    - Title: "Protonation State of Amino Acid vs. pH".
#    - Include a legend indicating pKa.
#
# ### Example Usage
# ```python
# pKa_val = 4.75  # Example pKa for an amino acid
# pH_range = np.linspace(2, 12, 100)  # pH values from 2 to 12
# estimate_protonation(pKa_val, pH_range)
# ```
#
# ### Hints
# - You may need to rearrange the Henderson-Hasselbalch equation to solve for $[HA]$.
# - Use numpy and matplotlib for calculations and plotting.
# - Remember to label your axes and provide a legend for clarity.tions, and data visualization. Good luck!

# %%
# Import necessary libraries
import numpy as np
import matplotlib.pyplot as plt

def estimate_protonation(pKa, pH_range):
    """
    Estimate the proportion of protonated amino acid molecules in a solution at a given pH and pKa.
    :param pKa: Acid dissociation constant of the amino acid.
    :param pH_range: A range of pH values.
    :return: Plot showing the relationship between pH and the proportion of protonated amino acid.
    """
    # Calculate the proportion of protonated amino acid (HA) using the rearranged Henderson-Hasselbalch equation:
    # [HA] = 1 / (1 + 10^(pH - pKa))
    proportion_HA = 1 / (1 + 10 ** (pH_range - pKa))

    # Plotting
    plt.figure(figsize=(8, 6))
    plt.plot(pH_range, proportion_HA, label=f'pKa = {pKa}')
    plt.axvline(x=pKa, color='r', linestyle='--', label='pKa')
    plt.title('Protonation State of Amino Acid vs. pH')
    plt.xlabel('pH')
    plt.ylabel('Proportion of Protonated Amino Acid (HA)')
    plt.legend()
    plt.grid(True)
    plt.show()

    return proportion_HA

# Example usage
pKa_val = 4.5  # Example pKa for an amino acid
pH_range = np.linspace(0, 14, 100)  # pH values from 2 to 12
estimate_protonation(pKa_val, pH_range)

# Extend the concept: 
# What happens if you change the pKa? How should we interprate this?
# What happens if you change the pH range?
# Out:
# array([9.99968378e-01, 9.99956208e-01, 9.99939354e-01, 9.99916014e-01,
#        9.99883693e-01, 9.99838935e-01, 9.99776957e-01, 9.99691138e-01,
#        9.99572312e-01, 9.99407798e-01, 9.99180054e-01, 9.98864826e-01,
#        9.98428600e-01, 9.97825105e-01, 9.96990537e-01, 9.95837058e-01,
#        9.94244020e-01, 9.92046243e-01, 9.89018568e-01, 9.84855972e-01,
#        9.79148778e-01, 9.71353326e-01, 9.60760258e-01, 9.46465933e-01,
#        9.27358151e-01, 9.02135474e-01, 8.69388461e-01, 8.27775679e-01,
#        7.76316169e-01, 7.14778818e-01, 6.44073844e-01, 5.66472181e-01,
#        4.85467572e-01, 4.05219344e-01, 3.29735349e-01, 2.62115827e-01,
#        2.04139804e-01, 1.56271411e-01, 1.17963867e-01, 8.80666698e-02,
#        6.51867323e-02, 4.79385803e-02, 3.50829451e-02, 2.55821563e-02,
#        1.86046613e-02, 1.35038937e-02, 9.78763667e-03, 7.08674267e-03,
#        5.12729996e-03, 3.70760863e-03, 2.67995485e-03, 1.93658660e-03,
# ...
