# %% [markdown]
# # A Primer on Simulation and Plotting in Python
#
# `Simulation` in Python allows you to `model` real-world processes or systems. To do this, you will use known mathematical relationships in combination with random (or systematic) number generating functions to create data that approximates what you might see in the 'real' world. This is a powerful way to hone your `estimands` and `hypotheses` before doing an experiment in the lab.
#
# ### Key Concepts
# - **Modeling**: Representing a system or process through Python code. This could involve equations, algorithms, or rule-based systems.
# - **Parameters**: Defining variables that can be adjusted to see how they affect the outcome of the simulation.
# - **Iteration**: Running the simulation over a range of values or a period to observe different behaviors or outcomes.
# - **Data Generation**: Creating data that represents what would be observed in the real world or experiment.
#
# ## Plotting
# Plotting is about visualizing data in a graphical format. Python offers libraries like Matplotlib for creating a wide range of plots and charts.
#
# ### Key Concepts
# - **Data Visualization**: The process of converting data into a graphical or pictorial format, making it easier to understand, interpret, and derive insights.
# - **Graph Types**: Choosing the right type of graph for your data, such as line plots, scatter plots, bar charts, histograms, etc.
# - **Axes and Labels**: Properly labeling the axes and providing titles to make the plot informative.
# - **Customization**: Adjusting colors, sizes, labels, and other aesthetics to make the plot clear and appealing.
#
# ## Integration of Simulation and Plotting
# Combining simulation and plotting is powerful in Python. Simulations can generate data, which can then be visualized using plots.
#
# ### Workflow
# 1. **Define the Simulation**: Set up the model, parameters, and range of values.
# 2. **Run the Simulation**: Generate data by running the simulation.
# 3. **Plot the Results**: Use plotting libraries to visualize the data from the simulation.
# 4. **Analysis**: Interpret the plots to gain insights into the behavior of the system being simulated.
#
# ## Conclusion
# Simulation and plotting in Python are indispensable tools in scientific computing. They allow for the exploration of theoretical models, prediction of outcomes, and effective communication of complex data and concepts through visual representation.
#  through visual representation.

# %% [markdown]
# ## Code Examples

# %%
# Importing necessary libraries
import numpy as np
import matplotlib.pyplot as plt

# Python Simulation and Plotting in Biochemistry
# ----------------------------------------------

# Simulating a Biochemical Reaction: Enzyme Kinetics
# --------------------------------------------------
# Example: Simulating the Michaelis-Menten kinetics of an enzyme-catalyzed reaction
def michaelis_menten(substrate_concentration, vmax, km):
    return (vmax * substrate_concentration) / (km + substrate_concentration)

# Generating a range of substrate concentrations
substrate_concentrations = np.linspace(0, 100, 100)

# Calculating reaction rates for each concentration
reaction_rates = [michaelis_menten(s, 100, 10) for s in substrate_concentrations]

# Plotting the Reaction Rate vs. Substrate Concentration
plt.figure(figsize=(8, 6))
plt.plot(substrate_concentrations, reaction_rates, label='Michaelis-Menten Kinetics')
plt.xlabel('Substrate Concentration')
plt.ylabel('Reaction Rate')
plt.title('Enzyme Kinetics: Reaction Rate vs. Substrate Concentration')
plt.legend()
plt.show()

# Simulating and Plotting pH Changes in a Buffer Solution
# -------------------------------------------------------
# Example: Simulating how the addition of acid affects the pH of a buffer solution
def buffer_ph_change(initial_ph, acid_concentration, buffer_capacity):
    # Simplified model for demonstration
    return initial_ph - acid_concentration / buffer_capacity

# Simulating the addition of acid
acid_concentrations = np.linspace(0, 10, 100)
ph_changes = [buffer_ph_change(7.4, a, 50) for a in acid_concentrations]

# Plotting the pH change vs. Acid Concentration
plt.figure(figsize=(8, 6))
plt.plot(acid_concentrations, ph_changes, label='Buffer pH Change', color='red')
plt.xlabel('Acid Concentration')
plt.ylabel('pH')
plt.title('Buffer Solution: pH Change vs. Acid Concentration')
plt.legend()
plt.show()

# Conclusion
# ----------
# This code block demonstrates the use of simulation and plotting in Python,
# showing how they can be applied in scientific computing for biochemistry.
# These tools are essential for visualizing and understanding complex biochemical processes.

# %% [markdown]
# # Exercises
#
# ## Exercise 1: Enzyme Kinetics Simulation
# - **Task**: Write a function to simulate and plot the Lineweaver-Burk plot of an enzyme-catalyzed reaction. Use the Michaelis-Menten equation for the simulation.
# - **Hint**: The Lineweaver-Burk plot is a double reciprocal plot (1/rate vs. 1/[S]).
#
# ## Exercise 2: pH Titration Curve
# - **Task**: Simulate and plot a titration curve for a weak acid. Assume the acid has a pKa of 4.75 and simulate the addition of a strong base.
# - **Hint**: Use the Henderson-Hasselbalch equation to calculate pH: pH = pKa + log10([A-]/[HA]).
#
# ## Exercise 3: Temperature Effect on Reaction Rate
# - **Task**: Simulate how temperature affects the reaction rate of an enzyme. Assume the rate doubles for every 10°C increase in temperature.
# - **Hint**: Create a range of temperatures and calculate the corresponding reaction rates. Plot these values.
#
# ## Exercise 4: Substrate Saturation Curve
# - **Task**: Write a function to simulate and plot a substrate saturation curve for an enzyme, showing how the reaction rate varies with substrate concentration.
# - **Hint**: Use the Michaelis-Menten equation and vary the substrate concentration over a realistic range.
#
# ## Exercise 5: Dynamic Simulation of a Biochemical Pathway
# - **Task**: Create a simple dynamic simulation of a biochemical pathway (e.g., glycolysis) where the concentration of intermediates changes over time. Plot the concentrations of these intermediates over time.
# - **Hint**: Use a loop to update the concentrations and store them in lated tasks. Good luck!

# %%
# Your Answers Here

# %% [markdown]
# ## Solutions

# %%
# Importing necessary libraries
import numpy as np
import matplotlib.pyplot as plt

# Exercise 1: Enzyme Kinetics Simulation (Lineweaver-Burk Plot)
def lineweaver_burk_plot(vmax, km):
    substrate_concentrations = np.linspace(1e-4, 0.1, 100)
    reaction_rates = (vmax * substrate_concentrations) / (km + substrate_concentrations)
    plt.plot(1/substrate_concentrations, 1/reaction_rates)
    plt.xlabel('1/[S]')
    plt.ylabel('1/Rate')
    plt.title('Lineweaver-Burk Plot')
    plt.show()

lineweaver_burk_plot(100, 10)

# Exercise 2: pH Titration Curve
def titration_curve(pka, base_concentration):
    acid_concentration = np.linspace(1e-4, 0.1, 100)
    ph_values = pka + np.log10(base_concentration / acid_concentration)
    plt.plot(acid_concentration, ph_values)
    plt.xlabel('Acid Concentration')
    plt.ylabel('pH')
    plt.title('Titration Curve')
    plt.show()

titration_curve(4.75, 0.1)

# Exercise 3: Temperature Effect on Reaction Rate
def temperature_effect(initial_rate, temp_range):
    rates = [initial_rate * 2**(temp/10) for temp in temp_range]
    plt.plot(temp_range, rates)
    plt.xlabel('Temperature (°C)')
    plt.ylabel('Reaction Rate')
    plt.title('Temperature Effect on Enzyme Reaction Rate')
    plt.show()

temperature_effect(1, range(0, 100, 10))

# Exercise 4: Substrate Saturation Curve
def substrate_saturation_curve(vmax, km):
    substrate_concentrations = np.linspace(0, 100, 100)
    reaction_rates = (vmax * substrate_concentrations) / (km + substrate_concentrations)
    plt.plot(substrate_concentrations, reaction_rates)
    plt.xlabel('Substrate Concentration')
    plt.ylabel('Reaction Rate')
    plt.title('Substrate Saturation Curve')
    plt.show()

substrate_saturation_curve(100, 10)

# Exercise 5: Dynamic Simulation of a Biochemical Pathway
def simulate_pathway(steps, time_points):
    concentrations = np.zeros((len(time_points), len(steps)))
    for t in range(1, len(time_points)):
        for i, step in enumerate(steps):
            concentrations[t, i] = concentrations[t-1, i] + step(concentrations[t-1, i])
    for i in range(len(steps)):
        plt.plot(time_points, concentrations[:, i], label=f'Intermediate {i+1}')
    plt.xlabel('Time')
    plt.ylabel('Concentration')
    plt.title('Dynamic Simulation of Biochemical Pathway')
    plt.legend()
    plt.show()

# Example steps for a simple pathway
steps = [lambda x: np.sin(x) * 0.1, lambda x: np.cos(x) * 0.1]
simulate_pathway(steps, np.linspace(0, 10, 100))
