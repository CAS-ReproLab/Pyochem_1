# %% [markdown]
# # A Primer on Functions in Python
#
# Functions in Python are a way to encapsulate a set of instructions that can be used repeatedly. They allow for more organized, readable, and modular code. Here are the core concepts:
#
# 1. Function Definition
# A function is defined using the `def` keyword, followed by the function name and parentheses `()` which can enclose parameters. Notice the indentation, this is an important part of the syntax in python.
#
# ```python
# def function_name(parameters):
#     # Function body
#     return result
# ```
# 2. Parameters and Arguments
# - **Parameters** are variables listed inside the parentheses in the function definition.
# - **Arguments** are values passed to the function when it is called.
#
# 3. Return Statement
# - The `return` statement exits a function and optionally passes an expression back to the caller. A function without a return statement returns `None`.
#
# 4. Default Arguments
# - Functions can have default argument values. If the caller does not provide a value, the default is used.
#
# ```python
# def function_name(parameter=default_value):
#     # Function body
# ```
#
# 5. Keyword Arguments (kwargs)
# - When calling functions, you can specify arguments by the names of their corresponding parameters, regardless of their order.
#
# ```python
# function_name(parameter1=value1, parameter2=value2)
# ```
#
# 6. Variable Scope
# - Variables defined inside a function are local to that function.
# - Variables defined outside are global and can be read (but not directly modified) inside functions.
#
# 7. Docstrings
# - Docstrings are optional but recommended. They are used to describe what the function does. Sort of like multi-line comments.
#
# ```python
# def function_name():
#     #Description of the function.
# ```
#
# 8. Lambda Functions
# - Lambda functions are small anonymous functions defined with the `lambda` keyword. They can have any number of arguments but only one expression.
#
# ```python
# lambda arguments: expression
# ```
#
# 9. Higher-Order Functions
# - Functions that take other functions as arguments or return them as results are called higher-order functions.
#
# 10. Recursion
# - Functions can call themselves in their definition. This is known as recursion.
#  essential for writing clean, efficient, and reusable code.

# %% [markdown]
# ## Exercise 1: Calculating Molecular Weight Using Functions

# %%
# Example 1: Function
# -------------------
# Goal: Define a function that calculates the molecular weight of a compound
# based on its chemical formula using a dictionary of element weights.

import numpy as np

def calculate_molecular_weight(formula):
    """
    Calculate the molecular weight of a compound.
    
    Args:
        formula (dict): A dictionary representing the chemical formula.
                        Keys are elements (str) and values are counts (int).
                    
    Returns:
        float: Molecular weight of the compound.
    """

    # Step 1: Define atomic weights for common elements
    weights = {'H': 1.01, 'C': 12.01, 'N': 14.01, 'O': 16.00, 'S': 32.07}
    
    # Step 2: Calculate total molecular weight using dictionary comprehension
    molecular_weight = sum(weights[element] * count for element, count in formula.items())
    
    # Step 3: Return the result
    return molecular_weight

# Step 4: Create a dictionary for water (H₂O)
water = {'H': 2, 'O': 1}

# Step 5: Call the function and print the result
print("Molecular weight of water:", calculate_molecular_weight(water))
# Out:
# Molecular weight of water: 18.02

# %% [markdown]
# ## Troubleshooting practice

# %%
# Troubleshooting Practice: Calculating Molecular Weight (Fix the errors!)
# ------------------------------------------------------------------------
# Goal: Fix the code so that it correctly calculates the molecular weight of methane (CH₄).

import numpy as np

def calculate_molecular_weight(formula)
    """
    Calculate the molecular weight of a compound.
    """
    weights = {'H': 1.01, 'C': 12.01, 'N': 14.01, 'O': 16.00, 'S': 32.07}
    
    molecular_weight = sum(weights[element] * count for element, count in formula.item())
    return molecularweight

methane = {'C': 1, 'H': 4}
print("Molecular weight of methane:", calculate_molecular_Weight(methane))

# %% [markdown]
# ## Your turn

# %%
# Your Turn
# ----------
# Task:
# 1. Define a function called calculate_mass()
#    that computes the molecular weight of carbon dioxide (CO₂).
# 2. Use the same element weights dictionary inside the function.
# 3. Create a dictionary for CO₂ → {'C': 1, 'O': 2}
# 4. Print the result in the format:
#    "Molecular weight of CO2: <value>"

# Write your code below:

# %% [raw]
# Desired Output:
#
# Molecular weight of CO2: 44.01

# %% [markdown]
# ## Exercise 2: Function with Default Arguments

# %%
# Example 2: Function with Default Arguments
# ------------------------------------------
# Goal: Define a function that calculates the concentration of a solution.
# This function demonstrates how to use default parameter values in Python.

def calculate_concentration(moles, volume, unit='M'):
    """
    Calculate the concentration of a solution.
    
    Args:
        moles (float): Number of moles of solute.
        volume (float): Volume of the solution in liters.
        unit (str, optional): Concentration unit ('M' for molarity, default).
    
    Returns:
        float: Concentration of the solution.
    """

    # Step 1: Calculate concentration using the formula: C = moles / volume
    concentration = moles / volume

    # Step 2: Return concentration in molarity (M) if supported
    if unit == 'M':
        return concentration
    else:
        # Step 3: Raise an error for unsupported units
        raise ValueError("Unsupported unit. Use 'M' for molarity.")

# Step 4: Call the function using default unit ('M')
print("Concentration:", calculate_concentration(0.5, 1), "M")
# Out:
# Concentration: 0.5 M

# %% [markdown]
# ## Trouble shooting practice

# %%
# Troubleshooting Practice: Default Arguments (Fix the errors!)
# -------------------------------------------------------------
# Goal: Fix the function so it correctly calculates concentration of NaCl solution.

def calculate_concentration(moles, volume, unit=M):
    """
    Calculate concentration of a solution.
    """
    concentration = moles / volumes
    if unit = 'M':
        return concentration
    else
        raise Valueerror("Unsupported unit. Use 'M' for molarity.")

print("Concentration:", calculate_concentration(1.0, 0.5))

# %% [markdown]
# ## Your turn

# %%
# Your Turn
# ----------
# Task:
# 1. Define a function called calculate_dilution()
#    that takes initial_concentration, final_volume, and initial_volume.
# 2. It should calculate and return the final concentration using:
#       C1 * V1 = C2 * V2  →  C2 = (C1 * V1) / V2
# 3. Give the function a default parameter: unit='M'
# 4. Print the result for:
#       initial_concentration=2.0, initial_volume=0.5, final_volume=1.0
# 5. Output format:
#       "Final concentration: <value> M"

# Write your code below:

# %% [raw]
# Desired Output:
#
# Final concentration: 1.0 M

# %% [markdown]
# ## Exercise 3: Higher-Order Function

# %%
# Example 3: Higher-Order Function
# --------------------------------
# Goal: Define a function that takes another function as an argument
# and applies it to every element of a list.

def apply_to_each_element(list, func):
    """
    Apply a function to each element in a list.
    
    Args:
        list (list): A list of elements.
        func (function): A function to apply to each element.
    
    Returns:
        list: A new list with the function applied to each element.
    """

    # Step 1: Use a list comprehension to apply 'func' to each element
    return [func(element) for element in list]

# Step 2: Create a list of temperatures in Celsius
temperatures_C = [0, 25, 100]

# Step 3: Convert Celsius to Fahrenheit using a lambda function
temperatures_F = apply_to_each_element(temperatures_C, lambda x: x * 9/5 + 32)

# Step 4: Print the converted list
print("Temperatures in Fahrenheit:", temperatures_F)
# Out:
# Temperatures in Fahrenheit: [32.0, 77.0, 212.0]

# %% [markdown]
# ## Troubleshooting practice

# %%
# Troubleshooting Practice: Higher-Order Function (Fix the errors!)
# -----------------------------------------------------------------
# Goal: Fix the code so it correctly converts Celsius to Fahrenheit.

def apply_to_each_element(list func):
    """
    Apply a function to each element in a list.
    """
    return [func(elements) for element in list]

temperatures_C = [0, 25, 100]
temperatures_F = apply_to_each_element(temperatures_C, lambda x: x * 9/5 + 32)
print("Temperatures in Fahrenheit" temperatures_F)

# %% [markdown]
# ## Your turn

# %%
# Your Turn
# ----------
# Task:
# 1. Define a function called apply_to_each_protein(proteins, func)
#    that applies a given function to each protein name in a list.
#
# 2. Create a list of protein names (as they might appear in conversation):
#       ["hemoglobin", "insulin", "actin", "collagen"]
#
# 3. Use your function to convert each protein name to an uppercase
#    gene-style label using:
#         lambda p: p.upper()
#
# 4. Print the resulting list with the label:
#       "Standardized names:", <list>
#
# Write your code below:

# %% [raw]
# Desired Output:
#
# Standardized names: ['HEMOGLOBIN', 'INSULIN', 'ACTIN', 'COLLAGEN']

# %% [markdown]
# ## Exercise 4: Recursive Function

# %%
# Example 4: Recursive Function
# -----------------------------
# Goal: Define a function that calculates the factorial of a number
# using recursion — a function that calls itself.

def factorial(n):
    """
    Calculate the factorial of a number.
    
    Args:
        n (int): A non-negative integer.
    
    Returns:
        int: The factorial of n.
    """

    # Step 1: Base case — stop recursion when n == 0
    if n == 0:
        return 1
    else:
        # Step 2: Recursive case — multiply n by factorial(n - 1)
        return n * factorial(n - 1)

# Step 3: Call the function and print the result
print("Factorial of 5:", factorial(5))
# Out:
# Factorial of 5: 120

# %% [markdown]
# ## Troubleshooting practice

# %%
# Troubleshooting Practice: Recursive Function (Fix the errors!)
# --------------------------------------------------------------
# Goal: Fix the code so it correctly computes the factorial of 4.

def factorial(n)
    """
    Calculate factorial recursively.
    """
    if n = 0:
        return 1
    else
        return n * factorial(n - 1)

print("Factorial of 4:", Factorial(4))

# %% [markdown]
# ## Your turn

# %%
# Your Turn
# ----------
# Task:
# 1. Define a recursive function called nucleotide_repeat(n)
#    that prints "AT" repeated n times (representing a simple DNA pattern).
# 2. Base case: if n == 0, return an empty string "".
# 3. Recursive case: return "AT" + nucleotide_repeat(n - 1)
# 4. Call nucleotide_repeat(4) and print the result in this format:
#       "DNA repeat pattern:", <value>

# Write your code below:

# %% [raw]
# Desired Output:
#
# DNA repeat pattern: ATATATAT

# %% [markdown]
# ## Exercise 5: Lambda Functions

# %%
# Example 5: Lambda Function
# ---------------------------
# Goal: Demonstrate how to use a lambda function for a simple calculation.

# Step 1: Create a lambda function that squares a number
square = lambda x: x ** 2

# Step 2: Call the lambda and print the result
print("Square of 4:", square(4))
# Out:
# Square of 4: 16

# %% [markdown]
# ## Troubleshooting Practice

# %%
# Troubleshooting Practice: Lambda Function (Fix the errors!)
# -----------------------------------------------------------
# Goal: Fix the code so it correctly computes the cube of a number using a lambda.

cube = lambda x x ** 3
print("Cube of 3" cube(3))

# %% [markdown]
# ## Your Turn

# %%
# Your Turn
# ----------
# Task:
# 1. Create a lambda function called convert_to_kDa
#    that converts molecular weight from Daltons to kilodaltons (kDa)
#    using the formula: 1 kDa = 1000 Da
# 2. Apply it to the following list of protein molecular weights (in Da):
#       [58000, 150000, 42000, 66000]
# 3. Store the converted values in a list called protein_kDa
# 4. Print the result in the format:
#       "Protein sizes in kDa:", <list>
#
# Write your code below:

# %% [raw]
# Desired Output:
#
# Protein sizes in kDa: [58.0, 150.0, 42.0, 66.0]

# %% [markdown]
# # Advanced Exercises
# Peak at the examples and solutions to get ideas. Don't copy/paste or you won't learn anything. Use comments to explain what each line does.
#
# 1. Exercise 1: Molecular Weight Calculator
# - Write a function `calculate_molecular_weight_v2` that takes a string representing a chemical formula (e.g., "H2O") and returns its molecular weight. Use a dictionary to map elements to their atomic weights.
#
# 3. Exercise 2: Dilution Calculator
# - Create a function `calculate_dilution` that calculates the final concentration of a solution after dilution. It should take initial concentration, initial volume, and final volume as arguments.
#
# 4. Exercise 3: Temperature Conversion
# - Modify the `apply_to_each_element` function to convert a list of temperatures in Fahrenheit to Celsius. Use a lambda function for the conversion.
#
# 5. Exercise 4: Recursive Function for Fibonacci Sequence
# - Write a recursive function `fibonacci` that returns the nth number in the Fibonacci sequence.
#
# 6. Exercise 5: Lambda Function for pH Calculation
# - Create a lambda function `calculate_pH` that calculates the pH given the concentration of H+ ions in a solution.
#
# 7. Exercise 6: Data Analysis with Higher-Order Functions
# - Given a list of absorbance readings from a spectrophotometer, use `apply_to_each_element` to convert each reading to transmittance.
#
# 8. Exercise 7: Enzyme Kinetics
# - Write a function `calculate_reaction_rate` that calculates the rate of an enzyme-catalyzed reaction using the Michaelis-Menten equation. The function should take substrate concentration, Vmax, and Km as arguments.
#
# 9. Exercise 8: Plotting Function
# - Create a function `plot_data` that takes two lists (x and y values) and plots them using matplotlib. Add appropriate labels for a biochemical context.
#
# 10. Exercise 9: Unit Conversion Function
# - Write a function `convert_units` that converts between different units of concentration (e.g., from mM to µM).
#
# 11. Exercise 10: Error Handling in Functions
# - Modify the `calculate_concentration` function to include error handling that checks if the volume is zero and if the correct unit ('moles/liter or M') has been entered.

# %% [markdown]
# ### **AI Practice Prompt — Copy & Paste**
#
#  I’ve just completed a Python Functions module covering:
#  - Function definitions and parameters
#  - Default arguments
#  - Higher-order functions and lambdas
#  - Recursion
# > - Error handling
#  - Biochemistry applications (molecular weight, pH, enzyme kinetics, etc.)
#
# Please give me 3–5 new **practice problems** that test these skills together.
# Each problem should:
# - Involve a realistic biology or chemistry context (e.g., reactions, kinetics, concentrations, conversions, or plotting data).
# - Require writing a Python **function** (or small set of functions).
# - Include a short example input and the expected output.
# - Vary in difficulty (some simple, some challenging).
# After listing the problems, give me:
# - Hints or step-by-step solution outlines (not full code right away).
# - Then, after I try them, allow me to ask for corrected solutions.
#
# Make sure all problems reinforce **function writing, modular thinking, and documentation** using Python best practices.
