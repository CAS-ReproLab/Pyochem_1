# %% [markdown]
# # More on Pandas DataFrames
# pandas DataFrames are a fundamental tool in Python for data manipulation and analysis. Understanding these core concepts is essential for effective data handling in scientific computing, especially for large multivariate datasets.

# %% [markdown]
# ## DataFrame Basics and Key Components
# - **Definition**: A DataFrame is a two-dimensional, size-mutable, and potentially heterogeneous tabular data structure with labeled axes (rows and columns). `Pandas dataframes` are made of `pandas series` data structures. Each series is a column. They behave like `numpy arrays`.
# - **Creation**: DataFrames can be created from various data sources like lists, dictionaries, or reading from files (e.g., CSV, Excel).
# - **Rows and Columns**: DataFrames are composed of rows and columns, each row representing a record and each column a feature.
# - **Index**: Each row has an index, which can be numeric, string, or datetime. It's crucial for data alignment and manipulation.
# - **Data Types**: Columns can hold different types of data (integers, strings, floats, etc.).

# %%
# Sample dataframe
# Importing necessary libraries
import pandas as pd
import numpy as np

# Creating a DataFrame
# --------------------
# Example: Creating a DataFrame to store amino acid properties
# Start by creating a dictionary with amino acid molecular weights keyed to their corresponding amino acid name
amino_acids = {
    'AminoAcid': ['Alanine', 'Cysteine', 'Aspartic Acid', 'Glutamine'],
    'MolecularWeight': [89.1, 121.2, 133.1, 146.1],
    'pKa': [2.34, 1.96, 3.9, 2.17]
}
# Convert the dictionary to a dataframe
amino_acids_df = pd.DataFrame(amino_acids)
print("Amino Acids DataFrame:\n", amino_acids_df)
# Out:
# Amino Acids DataFrame:
#         AminoAcid  MolecularWeight   pKa
# 0        Alanine             89.1  2.34
# 1       Cysteine            121.2  1.96
# 2  Aspartic Acid            133.1  3.90
# 3      Glutamine            146.1  2.17

# %% [markdown]
# ## Trouble shooting practice

# %%
#(Fix the errors!)
# ----------------------------------------------------------------
# Goal: Create a DataFrame that stores enzyme optimal conditions.
# Start by creating a dictionary with enzyme info.

enzymes = {
    'Enzyme': ['Amylase', 'Lipase', 'Pepsin', 'Catalase'],
    'OptimalpH': [7.0, 8.0, 2.0, 7.0],
    'Temp_C': [37, 37, 37, 30]
}

# Convert the dictionary to a dataframe
enzyme_df = pd.dataframe(enzymes)
print("Enzyme Data Frame:\n", Enzyme_df)

# %% [raw]
# Desired output:
# Enzyme Data Frame:
#       Enzyme  OptimalpH  Temp_C
# 0   Amylase        7.0      37
# 1    Lipase        8.0      37
# 2    Pepsin        2.0      37
# 3  Catalase        7.0      30

# %% [markdown]
# ## Some useful descriptive methods
# The strength of dataframes are that the facilitate handling large, multivariate datasets. Here are some useful descriptive methods:
# 1. head() - View the first few rows of the DataFrame
# 2. tail() - View the last few rows of the DataFrame
# 3. describe() - Get a summary of statistics for numeric columns
# 4. info() - Get a concise summary of the DataFrame
# 5. mean() - Calculate the mean of each numeric column
# 6. median() - Calculate the median of each numeric column
#
# **Note**: Because these are `methods`, you'll call them by appending them onto your dataframe of interest: i.e., dataframe.head()

# %%
# Print the first five lines of amino_acids_df
print(amino_acids_df.head())

# Try swapping out .head() with other methods. What does each one do?
# Out:
#        AminoAcid  MolecularWeight   pKa
# 0        Alanine             89.1  2.34
# 1       Cysteine            121.2  1.96
# 2  Aspartic Acid            133.1  3.90
# 3      Glutamine            146.1  2.17

# %% [markdown]
# ## Data Manipulation, Merging, and Sorting
# Above, we saw how to look at the data, pandas also maintains many powerful methods for manipulating the data, including:
# - **Selection**: Accessing specific rows, columns, or cells using loc, iloc, or column names.
# - **Filtering**: Extracting a subset of rows based on a condition.
# - **Adding Columns**: Enhancing DataFrames by calculating new columns or adding data.
# - **Aggregation**: Performing statistical operations like mean, median, sum, etc., on columns.
# - **Merging**: Combining two DataFrames based on common columns.
# - **Reading Data**: Loading data from various file formats into DataFrames.
# - **Writing Data**: Exporting DataFrames to different file formats for storage or further analysis.
#
# Check the [documentation](https://pandas.pydata.org/docs/user_guide/index.html) for other useful applications such as:
#
# - **Joining**: Linking DataFrames using their indexes.
# - **Detection**: Identifying missing or NaN values in the DataFrame.
# - **Filling**: Replacing missing values with specific values or statistical measures (mean, median).
# - **Dropping**: Removing rows or columns with missing values.

# %% [markdown]
# ## Examples will be first, then trouble shooting, then trying it from scratch

# %%
# Creating a DataFrame
# --------------------
# Example: Creating a DataFrame to store properties of plant pigments
# Start by creating a dictionary with pigment names, absorption peaks, solubility, and max stable temperature.

import pandas as pd

plant_pigments = {
    'Pigment': ['Chlorophyll a', 'Chlorophyll b', 'Carotene', 'Xanthophyll', 'Anthocyanin'],
    'Absorption_nm': [430, 453, 480, 475, 530],
    'Solubility': ['Lipid', 'Lipid', 'Lipid', 'Lipid', 'Water'],
    'Max_Temp_C': [45, 45, 60, 55, 30]
}

pigment_df = pd.DataFrame(plant_pigments)
print("Plant Pigment DataFrame:\n", pigment_df)
# Out:
# Plant Pigment DataFrame:
#           Pigment  Absorption_nm Solubility  Max_Temp_C
# 0  Chlorophyll a            430      Lipid          45
# 1  Chlorophyll b            453      Lipid          45
# 2       Carotene            480      Lipid          60
# 3    Xanthophyll            475      Lipid          55
# 4    Anthocyanin            530      Water          30

# %% [markdown]
# ## Exercise 1: Data Access and Manipulation

# %%
# --------------------------------------
# Goal: From the pigment DataFrame, select and print
# only the pigment names and their max stable temperatures.

pigment_temps = pigment_df[['Pigment', 'Max_Temp_C']]
print("Pigment names and max temperatures:\n", pigment_temps)
# Out:
# Pigment names and max temperatures:
#           Pigment  Max_Temp_C
# 0  Chlorophyll a          45
# 1  Chlorophyll b          45
# 2       Carotene          60
# 3    Xanthophyll          55
# 4    Anthocyanin          30

# %% [markdown]
# ## Trouble Shooting

# %%
# Troubleshooting Practice: Selecting Columns (Fix the errors!)
# -------------------------------------------------------------
# Goal: Create a DataFrame called pigment_absorb
# that ONLY includes columns Pigment and Absorption_nm.

pigment_absorb = pigment_df[['Pigments', 'Absorbtion_nm']]
print("Absorbance Table:\n", pigment_absorbs)

# %% [markdown]
# ## Your turn

# %%
# Your Turn
# ---------
# Task:
# 1. Create a new DataFrame called solubility_only
#    that contains ONLY the columns 'Pigment' and 'Solubility'
# 2. Print solubility_only

# Write your code below:

# %% [raw]
# Desired Output:
#
#          Pigment        Solubility
# 0   Chlorophyll a            Lipid
# 1   Chlorophyll b            Lipid
# 2         Carotene           Lipid
# 3      Xanthophyll           Lipid
# 4      Anthocyanin           Water

# %% [markdown]
# ## Exercise 2: Filtering Data

# %%
# Goal: Filter and display pigments that absorb light
# at wavelengths greater than 470 nm.

high_absorb = pigment_df[pigment_df['Absorption_nm'] > 470]
print("Pigments with absorption > 470 nm:\n", high_absorb)
# Out:
# Pigments with absorption > 470 nm:
#         Pigment  Absorption_nm Solubility  Max_Temp_C
# 2     Carotene            480      Lipid          60
# 3  Xanthophyll            475      Lipid          55
# 4  Anthocyanin            530      Water          30

# %% [markdown]
# ## Trouble shooting practice

# %%
# Troubleshooting Practice: Filtering Rows (Fix the errors!)
# ----------------------------------------------------------
# Goal: Create a DataFrame called lipid_only
# that includes only rows where Solubility is 'Lipid'.

lipid_only = pigment_df[pigment_df['solubility'] == Lipid]
print("Lipids only:\n", lipid_only_df)

# %% [markdown]
# ## Your turn:

# %%
# Your Turn
# ---------
# Task:
# 1. Create a DataFrame called very_stable
#    that contains only pigments with Max_Temp_C > 50
# 2. Print very_stable

# Write your code below:

# %% [raw]
# Desired Output:
#
#        Pigment    Absorption_nm  Solubility  Max_Temp_C
# 2      Carotene             480       Lipid          60
# 3   Xanthophyll             475       Lipid          55

# %% [markdown]
# ## Exercise 3: Adding and Computing a New Column

# %%
# Goal: Add a new column called 'HeatStable'
# that is True if Max_Temp_C > 50, and False otherwise.

pigment_df['HeatStable'] = pigment_df['Max_Temp_C'] > 50
print("DataFrame with HeatStable column:\n", pigment_df)

# %% [markdown]
# ## Troubleshooting Practice

# %%
# Goal: Add a column 'WaterSoluble'
# that is True if Solubility == 'Water', else False.

pigment_df['WaterSoluble'] = pigment_df['Solubility'] = 'Water'
print("Updated table:\n", pigment_df['Water_Soluble'])

# %% [markdown]
# ## Your turn

# %%
# Your Turn
# ---------
# Task:
# 1. Create a new column called 'VisibleRange'
#    It should be 'Yes' if Absorption_nm is between 400 and 700 (inclusive),
#    and 'No' otherwise.
#
# Hint: You can use a condition like:
# (pigment_df['Absorption_nm'] >= 400) & (pigment_df['Absorption_nm'] <= 700)
#
# 2. Print pigment_df[['Pigment', 'Absorption_nm', 'VisibleRange']]

# Write your code below:

# %% [raw]
# Desired Output:
#
#          Pigment    Absorption_nm    VisibleRange
# 0   Chlorophyll a              430             Yes
# 1   Chlorophyll b              453             Yes
# 2         Carotene             480             Yes
# 3      Xanthophyll             475             Yes
# 4      Anthocyanin             530             Yes

# %% [markdown]
# ## Exercise 4: Merging Data Frames

# %%
# We will create a second DataFrame with info about biological role
# and merge it with pigment_df using the 'Pigment' column.

pigment_roles = {
    'Pigment': ['Chlorophyll a', 'Chlorophyll b', 'Carotene', 'Xanthophyll', 'Anthocyanin'],
    'Function': ['Primary light capture', 'Accessory light capture', 'Photoprotection', 'Photoprotection', 'Antioxidant / color']
}

roles_df = pd.DataFrame(pigment_roles)

merged_pigments = pd.merge(pigment_df, roles_df, on='Pigment')
print("Merged pigment data:\n", merged_pigments)
# Out:
# Merged pigment data:
#           Pigment  Absorption_nm Solubility  Max_Temp_C  \
# 0  Chlorophyll a            430      Lipid          45
# 1  Chlorophyll b            453      Lipid          45
# 2       Carotene            480      Lipid          60
# 3    Xanthophyll            475      Lipid          55
# 4    Anthocyanin            530      Water          30
#
#                   Function
# 0    Primary light capture
# 1  Accessory light capture
# 2          Photoprotection
# 3          Photoprotection
# 4      Antioxidant / color

# %% [markdown]
# ## Trouble shooting practice

# %%
# Troubleshooting Practice: Merging (Fix the errors!)
# ---------------------------------------------------
# Goal: Merge pigment_df and roles_df into full_info

full_info = pd.merge(pigment_df, roles_df, on='PigmentName')
print("Full info table:\n", Full_Info)

# %% [markdown]
# ## Your Turn

# %%
# Task:
# 1. Create a new DataFrame called sources_df with:
#    'Pigment': ['Chlorophyll a', 'Chlorophyll b', 'Carotene', 'Xanthophyll', 'Anthocyanin']
#    'SourceTissue': ['Thylakoid membrane', 'Thylakoid membrane', 'Chloroplasts', 'Chloroplasts', 'Vacuole of plant cell']
#
# 2. Merge merged_pigments with sources_df on 'Pigment'
#    and store the result in pigment_full
#
# 3. Print pigment_full

# Write your code below:

# %% [raw]
# Desired Output (pigment_full):
#
#          Pigment    Absorption_nm  Solubility  Max_Temp_C  HeatStable  WaterSoluble  Function
# 0   Chlorophyll a              430      Lipid          45       False        False   Primary light capture
# 1   Chlorophyll b              453      Lipid          45       False        False   Accessory light capture
# 2         Carotene             480      Lipid          60        True        False   Photoprotection
# 3      Xanthophyll             475      Lipid          55        True        False   Photoprotection
# 4      Anthocyanin             530      Water          30       False         True   Antioxidant / color
#
#          SourceTissue
# 0   Thylakoid membrane
# 1   Thylakoid membrane
# 2        Chloroplasts
# 3        Chloroplasts
# 4   Vacuole of plant cell

# %%
# Troubleshooting Practice: Filling Missing Data (Fix the errors!)
# ----------------------------------------------------------------
# Goal: Replace missing StabilityScore values with the average of the column.

merged_stability['StabilityScore'] = merged_stability['StabilityScore'].fillna(merged_stability['StabilityScore'].means)
print("Cleaned table:\n", mergedStability)

# %% [markdown]
# ## Exercise 5: Handling Missing Data

# %%
# Exercise 6: Handling Missing Data
# ---------------------------------
# We'll make a new DataFrame with pigment thermal stability scores,
# but some are missing (None). Then we will merge and fill them.

stability_data = {
    'Pigment': ['Chlorophyll a', 'Chlorophyll b', 'Carotene', 'Xanthophyll', 'Anthocyanin'],
    'StabilityScore': [0.6, None, 0.9, 0.8, None]  # None becomes NaN in pandas
}

stability_df = pd.DataFrame(stability_data)

merged_stability = pd.merge(pigment_df, stability_df, on='Pigment')
print("Before filling missing values:\n", merged_stability)

mean_score = merged_stability['StabilityScore'].mean()
merged_stability['StabilityScore'] = merged_stability['StabilityScore'].fillna(mean_score)

print("\nAfter filling missing values:\n", merged_stability)
# Out:
# Before filling missing values:
#           Pigment  Absorption_nm Solubility  Max_Temp_C  StabilityScore
# 0  Chlorophyll a            430      Lipid          45             0.6
# 1  Chlorophyll b            453      Lipid          45             NaN
# 2       Carotene            480      Lipid          60             0.9
# 3    Xanthophyll            475      Lipid          55             0.8
# 4    Anthocyanin            530      Water          30             NaN
#
# After filling missing values:
#           Pigment  Absorption_nm Solubility  Max_Temp_C  StabilityScore
# 0  Chlorophyll a            430      Lipid          45        0.600000
# 1  Chlorophyll b            453      Lipid          45        0.766667
# 2       Carotene            480      Lipid          60        0.900000
# 3    Xanthophyll            475      Lipid          55        0.800000
# 4    Anthocyanin            530      Water          30        0.766667

# %% [markdown]
# ## Troubleshooting Practice

# %%
# Goal: Replace missing StabilityScore values with the average of the column.

merged_stability['StabilityScore'] = merged_stability['StabilityScore'].fillna(merged_stability['StabilityScore'].means)
print("Cleaned table:\n", mergedStability)

# %% [markdown]
# ## Your Turn

# %%
# Your Turn
# ---------
# Task:
# 1. Create a new DataFrame called cleaned_stability
#    that keeps only these columns after filling:
#    ['Pigment', 'StabilityScore']
#
# 2. Print cleaned_stability

# Write your code below:

# %% [markdown]
# # AI Prompt for Practicing Pandas (Step-by-Step with Examples)
#
# Use this prompt to guide your AI assistant while learning **pandas**.
# It’s designed for **interactive practice** — you’ll use *your dataset*, and the AI will use a **different example dataset** to demonstrate each concept without giving you your actual code.
#
#
#
#
#
#  **Prompt:**
#  “I’m learning pandas. Please teach me step-by-step using *my own dataset*, but show me examples using a *different dataset* from mine for demonstration.
#
#  Here’s how I want the session to go:
#
#  1️⃣ **Explain** the concept briefly in simple terms.
#  2️⃣ **Show a mini example** using a *different dataset* (e.g., gene expression, amino acids, etc.).
#  3️⃣ **Ask me** to try the same concept on *my dataset*, without giving me any code.
#  4️⃣ **Wait** for me to share my code and output.
#  5️⃣ **Review** my work, provide feedback, and explain any mistakes.
#  6️⃣ **Move on** to the next topic only after confirming I understand.
#
#  Please cover the following pandas concepts step-by-step:
#  - Creating DataFrames
#  - Viewing data (`head()`, `tail()`, `describe()`, `info()`)
#  - Selecting columns and rows
#  - Filtering with conditions
#  - Adding computed columns
#  - Grouping and aggregating (`groupby()`, `mean()`, etc.)
#  - Merging and joining DataFrames
#  - Handling missing data (`isna()`, `fillna()`, `dropna()`)
#  - Sorting and ordering data
#  - Reading and writing CSV files
#
#  Additional rules:
#  - If I make an **error**, explain what it means and how to fix it — don’t rewrite my entire code.
#  - If I’m **stuck**, give another short example (with a different dataset) to illustrate.
#  - Ask me small **reflection questions** (e.g., “What does describe() tell you about your data?”).
#  - Keep all your demo examples related to **data science or biology** (e.g., proteins, enzymes, plants, metabolites).
#  - Never give me the exact code for my dataset — only use your **own example**.”
